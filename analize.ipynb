# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('vgsales.csv')
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data = data.dropna()
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16593    False
# 16594    False
# 16595    False
# 16596    False
# 16597    False
# Length: 16291, dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
data['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
data ['Year']=pd.to_datetime(data['Year'], format='%Y')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  datetime64[ns]
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(4)
# memory usage: 1.5+ MB
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\2584329618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data['Genre'].value_counts()
# Out:
# Genre
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: count, dtype: int64

# %%
sns.countplot(x='Genre',data=data,order=data['Genre'].value_counts().index)
plt.xticks(rotation=90);

# %%
numeric_colums = data.select_dtypes(include=['float64', 'int64'])

correlation = numeric_colums.corr()

plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title ('Pairwise Correlation of Video Game Sales Features')
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.lineplot(data=data, x='Year', y='Genre', hue='Genre', palette='tab10')

plt.xlabel('Year')
plt.ylabel('Sales (in millions)')
plt.title('Video Game Sales Over the Years')
plt.legend(title='Sales Category', loc='upper left')
plt.grid(True)
plt.show()
# Out:
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
area_sales = data[['NA_Sales','EU_Sales', 'JP_Sales', 'Other_Sales']]
area_sales = area_sales.melt(var_name='Area',value_name='Total_Sales')
area_sales = area_sales.groupby('Area')['Total_Sales'].sum().reset_index()

plt.figure(figsize=(10,5))
plt.pie(area_sales['Total_Sales'],labels=area_sales['Area'],colors=sns.color_palette('magma_r'),autopct='%.2f%%')
plt.show()

# %%
#top 10 publishers
top_publishers = data['Publisher'].value_counts().head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top_publishers.values,y=top_publishers.index,palette='viridis')
plt.title('Top 10 Publishers')
plt.xlabel('Number of Games Published')
plt.ylabel('Publisher')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\3943840120.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_publishers.values,y=top_publishers.index,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
#botton 10 publishers

bottom_publishers = data['Publisher'].value_counts().tail(10)
plt.figure(figsize=(10,5))
sns.barplot(x=bottom_publishers.values,y=bottom_publishers.index,palette='viridis')
plt.title('Bottom 10 Publishers')
plt.xlabel('Number of Games Published')
plt.ylabel('Publisher')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\2869032704.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bottom_publishers.values,y=bottom_publishers.index,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# all sales JP 
jp_sales = data.groupby('Year')['JP_Sales'].sum().reset_index()
plt.figure(figsize=(12,6))
sns.lineplot(data=jp_sales,x='Year',y='JP_Sales',color='purple')
plt.title('JP Sales Over the Years')
plt.xlabel('Year')
plt.ylabel('Sales (in millions)')
plt.grid(True)
plt.show()

# %%
#all sales NA

na_sales = data.groupby('Year')['NA_Sales'].sum().reset_index()
plt.figure(figsize=(12,6))
sns.lineplot(data=na_sales,x='Year',y='NA_Sales',color='purple')
plt.title('NA Sales Over the Years')
plt.xlabel('Year')
plt.ylabel('Sales (in millions)')
plt.grid(True)
plt.show()

# %%
# all sales EU

eu_sales = data.groupby('Year')['EU_Sales'].sum().reset_index()
plt.figure(figsize=(12,6))
sns.lineplot(data=eu_sales,x='Year',y='EU_Sales',color='purple')
plt.title('EU Sales Over the Years')
plt.xlabel('Year')
plt.ylabel('Sales (in millions)')
plt.grid(True)
plt.show()

# %%
# all sales Other

other_sales = data.groupby('Year')['Other_Sales'].sum().reset_index()
plt.figure(figsize=(12,6))
sns.lineplot(data=other_sales,x='Year',y='Other_Sales',color='purple')
plt.title('Other Sales Over the Years')
plt.xlabel('Year')
plt.ylabel('Sales (in millions)')
plt.grid(True)
plt.show()

# %%
#list platforms
data['Platform'].value_counts()
# Out:
# Platform
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# GC       542
# 3DS      499
# PSV      410
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %%
# game by platform
plt.figure(figsize=(10,5))
sns.countplot(x='Platform',data=data,order=data['Platform'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number of Games by Platform')
plt.show()

# %%
# correlation between top 10 publisher and genre

top_publishers = data['Publisher'].value_counts().head(10).index
top_publisher_data = data[data['Publisher'].isin(top_publishers)]
plt.figure(figsize=(12,6))
sns.countplot(data=top_publisher_data,x='Publisher',hue='Genre',palette='viridis')
plt.title('Top 10 Publishers by Genre')
plt.xlabel('Publisher')
plt.ylabel('Number of Games')
plt.xticks(rotation=90)
plt.show()
# Out:
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# all shooter game by platform

shooter_games = data[data['Genre']=='Shooter']
plt.figure(figsize=(10,5))
sns.countplot(x='Platform',data=shooter_games,order=shooter_games['Platform'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number of Shooter Games by Platform')
plt.grid(True)
plt.show()

# %%
# all shooter game by the top 10 publishers

shooter_games = data[data['Genre']=='Shooter']
top_publishers = data['Publisher'].value_counts().head(10).index
shooter_games = shooter_games[shooter_games['Publisher'].isin(top_publishers)]
plt.figure(figsize=(10,5))
sns.countplot(x='Publisher',data=shooter_games,hue='Genre',palette='viridis')
plt.xticks(rotation=90)
plt.title('Number of Shooter Games by Top 10 Publishers')
plt.show()
# Out:
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
simulation_games = data[data['Genre']=='Simulation']
plt.figure(figsize=(10,5))
sns.countplot(x='Platform',data=simulation_games,order=simulation_games['Platform'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number of Simulation Games by Platform')
plt.grid(True)
plt.show()

# %%
RPG_games = data[data['Genre']=='Role-Playing']
plt.figure(figsize=(10,5))
sns.countplot(x='Platform',data=RPG_games,order=RPG_games['Platform'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number of Role-Playing Games by Platform')
plt.grid(True)
plt.show()

# %%
sport_games = data[data['Genre']=='Sports']
plt.figure(figsize=(10,5))
sns.countplot(x='Platform',data=sport_games,order=sport_games['Platform'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number of Sports Games by Platform')
plt.grid(True)
plt.show()

# %%
# game most sales
most_sales = data.groupby('Name')['Global_Sales'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=most_sales.values,y=most_sales.index,palette='viridis')
plt.title('Top 10 Games by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\1343571520.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_sales.values,y=most_sales.index,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# game minus sales
minus_sales = data.groupby('Name')['Global_Sales'].sum().sort_values(ascending=True).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=minus_sales.values,y=minus_sales.index,palette='viridis')
plt.title('Bottom 10 Games by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\733481578.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=minus_sales.values,y=minus_sales.index,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# random game
random_game = data.sample(10)
plt.figure(figsize=(10,5))
sns.barplot(x='Global_Sales',y='Name',data=random_game,palette='viridis')
plt.title('Random 10 Games by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\1915803169.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales',y='Name',data=random_game,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# all game with pokemon 
pokemon_games = data[data['Name'].str.contains('Pokemon')]
plt.figure(figsize=(10,5))
sns.countplot(x='Platform',data=pokemon_games,order=pokemon_games['Platform'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number of Pokemon Games by Platform')
plt.grid(True)
plt.show()

# %%
# list pokemon games with platform sort by platform

pokemon_games = data[data['Name'].str.contains('Pokemon')]
pokemon_games = pokemon_games.sort_values(by='Platform')
pokemon_games[['Name','Platform']]
# Out:
#                                                     Name Platform
# 10992                               Pokemon Rumble World      3DS
# 1702                       Pokemon Super Mystery Dungeon      3DS
# 4044                                 Pokemon Art Academy      3DS
# 1781                                Pokemon Rumble Blast      3DS
# 32                                   Pokemon X/Pokemon Y      3DS
# 49             Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS
# 1555          Pokemon Mystery Dungeon: Gates to Infinity      3DS
# 1178           Pokemon Mystery Dungeon: Explorers of Sky       DS
# 750                                       Pokemon Ranger       DS
# 692                     Pokemon Ranger: Shadows of Almia       DS
# 1986                                    Pokemon Conquest       DS
# 209    Pokemon Mystery Dungeon: Explorers of Time/Exp...       DS
# 2681                                        Pokemon Dash       DS
# ...

# %%
# 10 best game mario
mario_games = data[data['Name'].str.contains('Mario')]
mario_games = mario_games.sort_values(by='Global_Sales',ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x='Global_Sales',y='Name',data=mario_games,palette='viridis')
plt.title('Top 10 Mario Games by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')  
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\2661126051.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales',y='Name',data=mario_games,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# sonic game without mario
sonic_games = data[data['Name'].str.contains('Sonic')]
sonic_games = sonic_games[~sonic_games['Name'].str.contains('Mario')]
sonic_games = sonic_games.sort_values(by='Global_Sales',ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x='Global_Sales',y='Name',data=sonic_games,palette='viridis')
plt.title('Top 10 Sonic Games by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\3676906841.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales',y='Name',data=sonic_games,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# sonic's ultimate genisis collection

sonic_ultimate_genisis = data[data['Name'].str.contains('Sonic\'s Ultimate Genesis Collection')]
sonic_ultimate_genisis
# Out:
#       Rank                                 Name Platform       Year Genre  \
# 706    708  Sonic's Ultimate Genesis Collection      PS3 2009-01-01  Misc
# 1348  1350  Sonic's Ultimate Genesis Collection     X360 2009-01-01  Misc
#
#      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 706       Sega      1.34      0.62       0.0         0.31          2.27
# 1348      Sega      0.85      0.46       0.0         0.13          1.43

# %%
# list game sonic 
sonic_games = data[data['Name'].str.contains('Sonic the Hedgehog')]
sonic_games
# Out:
#         Rank                          Name Platform       Year     Genre  \
# 143      144          Sonic the Hedgehog 2      GEN 1992-01-01  Platform
# 254      255            Sonic the Hedgehog      GEN 1991-01-01  Platform
# 991      993          Sonic the Hedgehog 3      GEN 1994-01-01  Platform
# 1715    1717            Sonic the Hedgehog      PS3 2006-01-01  Platform
# 1983    1985            Sonic the Hedgehog     X360 2006-01-01  Platform
# 13525  13527  Sonic the Hedgehog 2 (8-bit)       GG 1992-01-01  Platform
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 143        Sega      4.47      1.20      0.16         0.19          6.03
# 254        Sega      3.03      0.91      0.26         0.13          4.34
# 991        Sega      1.02      0.47      0.20         0.07          1.76
# 1715       Sega      0.41      0.07      0.04         0.66          1.18
# 1983       Sega      0.44      0.49      0.00         0.11          1.05
# ...

# %%
# top 10 game release in 2011

games_2011 = data[data['Year'].dt.year==2011]
top_10_2011 = games_2011.sort_values(by='Global_Sales',ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x='Global_Sales',y='Name',data=top_10_2011,palette='viridis')
plt.title('Top 10 Games Released in 2011 by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\1230278074.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales',y='Name',data=top_10_2011,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# top 10 game release in 1998

games_1998 = data[data['Year'].dt.year==1998]
top_10_1998 = games_1998.sort_values(by='Global_Sales',ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x='Global_Sales',y='Name',data=top_10_1998,palette='viridis')
plt.title('Top 10 Games Released in 1998 by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\1242622071.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales',y='Name',data=top_10_1998,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
games_2002 = data[data['Year'].dt.year==2002]
top_10_2002 = games_2002.sort_values(by='Global_Sales',ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x='Global_Sales',y='Name',data=top_10_2002,palette='viridis')
plt.title('Top 10 Games Released in 2002 by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\821973276.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales',y='Name',data=top_10_2002,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
games_2004 = data[data['Year'].dt.year==2004]
top_10_2004 = games_2004.sort_values(by='Global_Sales',ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x='Global_Sales',y='Name',data=top_10_2004,palette='viridis')
plt.title('Top 10 Games Released in 1998 by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\3782352776.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales',y='Name',data=top_10_2004,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
games_2013 = data[data['Year'].dt.year==2013]
top_10_2013 = games_2013.sort_values(by='Global_Sales',ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x='Global_Sales',y='Name',data=top_10_2013,palette='viridis')
plt.title('Top 10 Games Released in 1998 by Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game')
plt.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6168\1710391306.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales',y='Name',data=top_10_2013,palette='viridis')
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\lukas\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# tomodachi life
tomodachi_life = data[data['Name'].str.contains('Tomodachi Life')]
tomodachi_life
# Out:
#      Rank            Name Platform       Year       Genre Publisher  NA_Sales  \
# 188   189  Tomodachi Life      3DS 2013-01-01  Simulation  Nintendo      0.96
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 188      2.02      1.89         0.28          5.15

# %%
# dora the explorer
dora_explorer = data[data['Name'].str.contains('Dora the Explorer')]
dora_explorer
# Out:
#         Rank                                               Name Platform  \
# 1956    1958         Dora the Explorer: Dora Saves the Mermaids       DS
# 3294    3296                     Dora the Explorer: Super Spies      GBA
# 4495    4497                      Dora the Explorer: Dora Puppy       DS
# 6385    6387  Dora the Explorer: Dora Saves the Crystal Kingdom      Wii
# 6529    6531  Dora the Explorer: The Search for Pirate Pig's...      GBA
# 6770    6772    Dora the Explorer: Journey to the Purple Planet      PS2
# 6906    6908           Dora the Explorer: Super Star Adventures      GBA
# 9826    9828         Dora the Explorer: Dora Saves the Mermaids      PS2
# 9961    9963    Dora the Explorer: Journey to the Purple Planet       GC
# 10900  10902  Dora the Explorer: Dora Saves the Crystal Kingdom      PS2
#
#             Year      Genre             Publisher  NA_Sales  EU_Sales  \
# 1956  2007-01-01   Platform  Take-Two Interactive      0.97      0.01
# ...

# %%
# game with the most letter
most_letter = data['Name'].apply(len).idxmax()
data.loc[most_letter]
# Out:
# Rank                                                         9720
# Name            DS Yamamura Misa Suspense: Maiko Kogiku - Kish...
# Platform                                                       DS
# Year                                          2008-01-01 00:00:00
# Genre                                                   Adventure
# Publisher                                              Tecmo Koei
# NA_Sales                                                      0.0
# EU_Sales                                                      0.0
# JP_Sales                                                     0.12
# Other_Sales                                                   0.0
# Global_Sales                                                 0.12
# Name: 9718, dtype: object

# %%
#rank 9720

rank_9720 = data.loc[9718]
rank_9720
# Out:
# Rank                                                         9720
# Name            DS Yamamura Misa Suspense: Maiko Kogiku - Kish...
# Platform                                                       DS
# Year                                          2008-01-01 00:00:00
# Genre                                                   Adventure
# Publisher                                              Tecmo Koei
# NA_Sales                                                      0.0
# EU_Sales                                                      0.0
# JP_Sales                                                     0.12
# Other_Sales                                                   0.0
# Global_Sales                                                 0.12
# Name: 9718, dtype: object
